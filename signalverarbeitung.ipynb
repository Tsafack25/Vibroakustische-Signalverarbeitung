# %%
import soundfile as sf

file_path = "audio.wav"
data, sample_rate = sf.read(file_path)

print(f"Sample Rate: {sample_rate} Hz")
print(f"Shape der Daten: {data.shape}")  # (Samples,) für Mono oder (Samples, 2) für Stereo
# Out:
# Sample Rate: 48000 Hz
# Shape der Daten: (461040, 2)
# [[  0   0]
#  [-41  -1]
#  [-14   0]
#  ...
#  [  8   2]
#  [-10  -4]
#  [  0   0]]
